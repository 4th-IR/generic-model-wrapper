# %%
import pandas as pd

df = pd.read_excel("torch_model_metrics.xlsx", sheet_name="Sheet1")
df.head(1000)
# Out:
#                      model_name  total_time_taken(mins)  memory_used  \
# 0                 wav2vec2_base                   11.88   137.093750
# 1                          gpt2                   48.51    49.156250
# 2   google/vit-base-patch16-224                    0.05     2.496094
# 3       facebook/detr-resnet-50                    0.03     0.257812
# 4                          gpt2                    0.03     0.250000
# 5   facebook/wav2vec2-base-960h                    0.02     0.000000
# 6                      resnet50                    0.03     0.000000
# 7                 wav2vec2_base                    0.03     0.000000
# 8             bert-base-uncased                    0.02     0.257812
# 9                   MobileNetV2                    0.03     0.000000
# 10                       YAMNet                    0.02     0.250000
# 11                         GPT2                    0.06     0.000000
# 12  google/vit-base-patch16-224                    0.04     2.101562
# ...

# %%
df.drop(index=range(2, 46), inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns=['level_0', 'index'], inplace=True)
