# %%
import pandas as pd

df = pd.read_excel("torch_model_metrics.xlsx", sheet_name="Sheet1")
df.tail(50)
# Out:
#                                    model_name  total_time_taken(mins)  \
# 36                          bert-base-uncased                    0.03
# 37                google/vit-base-patch16-224                    0.03
# 38                google/vit-base-patch16-224                    0.00
# 39                google/vit-base-patch16-224                    0.01
# 40                google/vit-base-patch16-224                    0.00
# 41                google/vit-base-patch16-224                    0.00
# 42                google/vit-base-patch16-224                    0.00
# 43                google/vit-base-patch16-224                    0.00
# 44                google/vit-base-patch16-224                    1.18
# 45                google/vit-base-patch16-224                   -0.02
# 46                google/vit-base-patch16-224                   19.10
# 47                    facebook/detr-resnet-50                    0.07
# ...

# %%
df.at[71, "model_name"] = "Qwen/Qwen-VL"
df.at[72, "model_name"] = "Salesforce/blip-image-captioning-base"
df.at[73, "model_name"] = "Salesforce/blip-image-captioning-base"
df.at[74, "model_name"] = "microsoft/git-base"
df.at[75, "model_name"] = "Salesforce/blip2-opt-2.7b"

# %%
df.head(-1)
# Out:
#                                model_name  total_time_taken(mins)  \
# 0                           wav2vec2_base                   11.88
# 1                                    gpt2                   48.51
# 2             google/vit-base-patch16-224                    0.05
# 3                 facebook/detr-resnet-50                    0.03
# 4                                    gpt2                    0.03
# ..                                    ...                     ...
# 72  Salesforce/blip-image-captioning-base                    2.47
# 73  Salesforce/blip-image-captioning-base                    1.37
# 74                     microsoft/git-base                    0.66
# 75              Salesforce/blip2-opt-2.7b                    0.05
# 76                                  vgg19                    4.57
#
#     memory_used  inference_time(s)  load_status  inference_status  \
# 0    137.093750                NaN            0                 0
# ...

# %%
df.drop(columns=['level_0', 'index'], inplace=True)
